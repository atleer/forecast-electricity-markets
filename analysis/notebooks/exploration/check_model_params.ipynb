# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
from pathlib import Path
import os

# %% [markdown]
# Change working directory

# %%
notebook_path = %pwd

os.chdir(Path(notebook_path).parent.parent.parent)
os.getcwd()
# Out:
# '/home/atleeri/repositories/forecasting/forecast-electricity-markets'

# %%
results/models/Seq2SeqGRU/2026-05-17

# %%
from src.training.device import set_device
device = set_device()
device
# Out:
# 'cpu'

# %%
model_name = 'Seq2SeqGRU'
date = '2026-05-17'
loadpath = Path(f'results/models/{model_name}/{date}/Run1/loss_val=0.657.pth', )

model_benchmark = torch.load(loadpath, map_location = device)

model_benchmark
# Out:
# {'stopped_epoch': 10,
#  'model_state_dict': OrderedDict([('encoder.weight_ih_l0',
#                tensor([[ 1.6964e-02, -8.1910e-02, -4.8250e-02],
#                        [-4.7307e-02,  1.2588e-02,  4.9930e-02],
#                        [-1.6737e-01, -2.0726e-01, -2.4154e-02],
#                        [ 7.8468e-03,  7.6250e-03,  1.0061e-01],
#                        [ 7.9233e-02,  1.3047e-01, -8.5371e-02],
#                        [ 7.8814e-02,  9.2585e-02,  2.8321e-02],
#                        [ 1.0234e-01,  4.8883e-02, -8.3396e-02],
#                        [ 1.1982e-02,  5.6327e-02, -1.1301e-01],
#                        [-2.3349e-01, -2.5434e-01, -3.5732e-02],
#                        [ 9.1150e-02, -3.3321e-01,  2.1903e-02],
#                        [ 6.9095e-02, -1.1172e-01, -2.0713e-01],
#                        [ 1.4819e-01, -5.0438e-02,  3.1098e-01],
#                        [-1.1368e-01, -1.3386e-01, -5.7231e-02],
# ...

# %%
model_benchmark['stopped_epoch']
# Out:
# 10

# %%
model_compare['stopped_epoch']
# Out:
# 1

# %%
model_name = 'Seq2SeqGRU'
date = '2026-07-12'
loadpath = Path(f'results/models/{model_name}/{date}/Run0/loss_val=0.790.pth', )

model_compare = torch.load(loadpath, map_location = device)

model_compare
# Out:
# {'stopped_epoch': 1,
#  'model_state_dict': OrderedDict([('encoder.weight_ih_l0',
#                tensor([[ 0.0558, -0.0520,  0.0949],
#                        [ 0.1457,  0.0828,  0.0879],
#                        [-0.0774,  0.0526,  0.0034],
#                        [ 0.0982, -0.0344, -0.0375],
#                        [ 0.1271,  0.0866, -0.0008],
#                        [-0.0539, -0.0458,  0.0717],
#                        [-0.0968, -0.1150, -0.0331],
#                        [ 0.0782, -0.1253,  0.1390],
#                        [ 0.1308,  0.0734,  0.0380],
#                        [ 0.0939,  0.0483,  0.1226],
#                        [-0.0027,  0.1190, -0.0928],
#                        [ 0.0377, -0.0580,  0.1194],
#                        [ 0.0672, -0.0521, -0.0821],
#                        [-0.0696, -0.1279, -0.0421],
#                        [-0.0357, -0.0729, -0.1349],
#                        [ 0.0130, -0.0679, -0.0281],
# ...
